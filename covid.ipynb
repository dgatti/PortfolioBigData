# %% [markdown]
# <a href="https://colab.research.google.com/github/dgatti/PortfolioBigData/blob/main/covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Sección nueva

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/DataSciencieICES/covid.csv', index_col= 'country')

# %%
df
# Out:
#              id      cases  ...  totalTests  testsPerOneMillion
# country                     ...
# World         1  236059904  ...           0                   0
# USA           2   44614321  ...   648216159             1944043
# India         3   33851005  ...   574252400              411057
# Brazil        4   21478546  ...    63776166              297388
# UK            5    7934936  ...   307339034             4497644
# ...         ...        ...  ...         ...                 ...
# Marshall I  220          4  ...           0                   0
# Samoa       221          3  ...           0                   0
# Saint Hele  222          2  ...           0                   0
# Micronesia  223          1  ...           0                   0
# China       224      96258  ...   160000000              111163
#
# [224 rows x 12 columns]

# %%
df.describe()
# Out:
#                id         cases  ...  testsPerOneMillion         CFR
# count  224.000000  2.240000e+02  ...        2.240000e+02  224.000000
# mean   112.500000  2.107678e+06  ...        1.063380e+06    0.021001
# std     64.807407  1.624083e+07  ...        1.904915e+06    0.027949
# min      1.000000  1.000000e+00  ...        0.000000e+00    0.000000
# 25%     56.750000  1.202025e+04  ...        6.887400e+04    0.008788
# 50%    112.500000  9.706400e+04  ...        4.166955e+05    0.014847
# 75%    168.250000  5.132688e+05  ...        1.243115e+06    0.024435
# max    224.000000  2.360599e+08  ...        1.441906e+07    0.250000
#
# [8 rows x 13 columns]

# %% [markdown]
# ## Tasa de Letalidad del COVID-19

# %%
df['CFR'] = df['deaths'] / df['cases']

# %%
df
# Out:
#              id      cases  ...  testsPerOneMillion       CFR
# country                     ...
# World         1  236059904  ...                   0  0.020421
# USA           2   44614321  ...             1944043  0.016161
# India         3   33851005  ...              411057  0.013272
# Brazil        4   21478546  ...              297388  0.027849
# UK            5    7934936  ...             4497644  0.017264
# ...         ...        ...  ...                 ...       ...
# Marshall I  220          4  ...                   0  0.000000
# Samoa       221          3  ...                   0  0.000000
# Saint Hele  222          2  ...                   0  0.000000
# Micronesia  223          1  ...                   0  0.000000
# China       224      96258  ...              111163  0.048162
#
# [224 rows x 13 columns]

# %%
paises_de_interes = df.loc[['World', 'Argentina', 'USA', 'China'], 'CFR']

# %%
paises_de_interes
# Out:
# country
# World        0.020421
# Argentina    0.021914
# USA          0.016161
# China        0.048162
# Name: CFR, dtype: float64

# %%
paises_de_interes = pd.DataFrame(paises_de_interes).reset_index()

# %%
paises_de_interes
# Out:
#      country       CFR
# 0      World  0.020421
# 1  Argentina  0.021914
# 2        USA  0.016161
# 3      China  0.048162

# %%
plt.stem(paises_de_interes['country'], paises_de_interes['CFR'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# <StemContainer object of 3 artists>
